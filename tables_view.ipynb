# %%
# %sql
SELECT * FROM f1_project.bronze.races_raw LIMIT 10;

# %%
# %sql
SELECT * FROM f1_project.bronze.drivers_raw;

# %%
# %sql
SELECT * FROM f1_project.bronze.constructors_raw;

# %%
# %sql
SELECT * FROM f1_project.bronze.results_raw LIMIT 30;

# %%
# %sql
SELECT * FROM f1_project.bronze.laps_raw LIMIT 10;

# %%
# %sql
SELECT * FROM f1_project.bronze.pit_stops_raw LIMIT 10;

# %%
# %sql
SELECT * FROM f1_project.silver.stg_drivers;

# %%
# %sql
SELECT * FROM f1_project.silver.stg_constructors;

# %%
# %sql
SELECT * FROM f1_project.silver.stg_results;

# %%
# %sql
SELECT driver_code, season, round, pit_lap_number, pit_in_time_ms, pit_out_time_ms, pit_duration_ms
FROM f1_project.silver.stg_pit_stops
ORDER BY season, round, driver_code, pit_lap_number
LIMIT 10;

# %%
# %sql
   SELECT driver_id, lap_number, position, gap_to_leader_ms
   FROM f1_project.gold.fact_lap_times
   WHERE season = 2023 AND round = 1 AND position = 1
   LIMIT 5;

# %%
# %sql
   SELECT COUNT(*) FROM f1_project.gold.fact_pit_stops WHERE driver_id IS NULL;
